# %%
import BayesNet
import networkx as nx
from BNReasoner import BNReasoner
import pandas as pd

# %%
path = 'testing/lecture_example.BIFXML'

# %%
bn = BayesNet.BayesNet()
bn.load_from_bifxml(path)

# %%
variables = bn.get_all_variables()
variables
variable = variables[0]

# %%
br = BNReasoner(bn)

# %%
br.bn.draw_structure()

# %%
br.prune(query=['Wet Grass?'], evidence=pd.Series({'Rain?': False, 'Winter?': True}))

# %%
br.bn.draw_structure()

# %%
# a
br.bn.get_cpt('Winter?')

# %%
# c
br.bn.get_cpt('Rain?')

# %%
# d
br.bn.get_cpt('Wet Grass?')
